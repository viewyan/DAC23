# %%
import pandas as pd
import matplotlib.pyplot as plt

print(pd.__version__)
# Out:
# 2.2.3

# %%
df = pd.read_csv('/Users/viewyan/Downloads/QMOF/qmof-bandgaps.csv')
print(df.head())
# Out:
#         refcode    BG_PBE   CBM_PBE   VBM_PBE  Direct_PBE
# 0  ABACUF01_FSR  0.632527  1.237645  0.605118       False
# 1    ABALOF_FSR  1.134232  3.430440  2.296208       False
# 2    ABAVIJ_FSR  0.345448  1.091140  0.745692       False
# 3    ABAVOP_FSR  0.342645  1.308492  0.965847        True
# 4    ABAXUZ_FSR  1.973007  1.855009 -0.117998       False

# %%
import matplotlib.pyplot as plt

plt.hist(df['BG_PBE'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Band Gap (eV)')
plt.ylabel('Number of MOFs')
plt.title('Distribution of Band Gaps in QMOF Dataset')
plt.grid(True)
plt.tight_layout()
plt.show()
